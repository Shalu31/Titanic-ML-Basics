# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'roll':[101,202,403,np.nan,105],'name':['shalu','verma','daddy','simmi',np.nan],'age':[21,np.nan,56,np.nan,87],'city':['kanpur','paris','germany','goa','india']})

# %%
df
# Out:
#     roll   name   age     city
# 0  101.0  shalu  21.0   kanpur
# 1  202.0  verma   NaN    paris
# 2  403.0  daddy  56.0  germany
# 3    NaN  simmi   NaN      goa
# 4  105.0    NaN  87.0    india

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    4 non-null      float64
#  1   name    4 non-null      object
#  2   age     3 non-null      float64
#  3   city    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.isnull().sum()
# Out:
# roll    1
# name    1
# age     2
# city    0
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1
# Out:
#     roll   name   age     city
# 0  101.0  shalu  21.0   kanpur
# 2  403.0  daddy  56.0  germany

# %%
df2 = df.dropna(axis=0,how='all')

# %%
df2
# Out:
#     roll   name   age     city
# 0  101.0  shalu  21.0   kanpur
# 1  202.0  verma   NaN    paris
# 2  403.0  daddy  56.0  germany
# 3    NaN  simmi   NaN      goa
# 4  105.0    NaN  87.0    india

# %%
df['color'] = ['red','blue','green','red','blue']

# %%
df
# Out:
#     roll   name   age     city  color
# 0  101.0  shalu  21.0   kanpur    red
# 1  202.0  verma   NaN    paris   blue
# 2  403.0  daddy  56.0  germany  green
# 3    NaN  simmi   NaN      goa    red
# 4  105.0    NaN  87.0    india   blue

# %%
df.loc[5] = [np.nan,np.nan,np.nan,np.nan,np.nan]

# %%
df
# Out:
#     roll   name   age     city  color
# 0  101.0  shalu  21.0   kanpur    red
# 1  202.0  verma   NaN    paris   blue
# 2  403.0  daddy  56.0  germany  green
# 3    NaN  simmi   NaN      goa    red
# 4  105.0    NaN  87.0    india   blue
# 5    NaN    NaN   NaN      NaN    NaN

# %%
df3 = df.dropna(axis=0,how='all')

# %%
df3
# Out:
#     roll   name   age     city  color
# 0  101.0  shalu  21.0   kanpur    red
# 1  202.0  verma   NaN    paris   blue
# 2  403.0  daddy  56.0  germany  green
# 3    NaN  simmi   NaN      goa    red
# 4  105.0    NaN  87.0    india   blue

# %%
df4 = df.dropna(thresh=4)

# %%
df5 = df.dropna(subset=['age','name'])

# %%
df6 = df.fillna(0)

# %%
df7 = df.fillna(method='ffill')
# Out:
# /tmp/ipython-input-31-2812626164.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df7 = df.fillna(method='ffill')

# %%
df.fillna({'age':df['age'].mean()})
# Out:
#     roll   name        age     city  color
# 0  101.0  shalu  21.000000   kanpur    red
# 1  202.0  verma  54.666667    paris   blue
# 2  403.0  daddy  56.000000  germany  green
# 3    NaN  simmi  54.666667      goa    red
# 4  105.0    NaN  87.000000    india   blue
# 5    NaN    NaN  54.666667      NaN    NaN

# %% [markdown]
# method = ffill/pad/bfill/backfill
# ffill/pad  ----forword filling
# bfill/backfill ---backward  filling

# %% [markdown]
# # loc ----to acess elements label wise
# # iloc --- to acess elements index wise

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'roll':[101,202,403,404,105],'name':['shalu','verma','daddy','simmi','priya'],'age':[21,22,56,45,87],'city':['kanpur','paris','germany','goa','india']})

# %%
df
# Out:
#    roll   name  age     city
# 0   101  shalu   21   kanpur
# 1   202  verma   22    paris
# 2   403  daddy   56  germany
# 3   404  simmi   45      goa
# 4   105  priya   87    india

# %%
df.loc[0]
# Out:
# roll       101
# name     shalu
# age         21
# city    kanpur
# Name: 0, dtype: object

# %%
df.loc[1][3]
# Out:
# /tmp/ipython-input-41-209379300.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[1][3]
# 'paris'

# %%
df.loc[[0,2]]
# Out:
#    roll   name  age     city
# 0   101  shalu   21   kanpur
# 2   403  daddy   56  germany

# %%
df.loc[df['age']>24]
# Out:
#    roll   name  age     city
# 2   403  daddy   56  germany
# 3   404  simmi   45      goa
# 4   105  priya   87    india

# %%
df.loc[df['age'] == df['age'].max()]
# display the person with highest age
# Out:
#    roll   name  age   city
# 4   105  priya   87  india

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'roll':[101,202,403,404,105],'name':['shalu','verma','daddy','simmi','priya'],'age':[21,22,56,45,87],'city':['kanpur','paris','germany','goa','india']})

# %%
df
# Out:
#    roll   name  age     city
# 0   101  shalu   21   kanpur
# 1   202  verma   22    paris
# 2   403  daddy   56  germany
# 3   404  simmi   45      goa
# 4   105  priya   87    india

# %%
df.iloc[0]
# Out:
# roll       101
# name     shalu
# age         21
# city    kanpur
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# roll       101
# name     shalu
# age         21
# city    kanpur
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    roll   name  age     city
# 0   101  shalu   21   kanpur
# 1   202  verma   22    paris
# 2   403  daddy   56  germany

# %%
df.loc[0:3]
# Out:
#    roll   name  age     city
# 0   101  shalu   21   kanpur
# 1   202  verma   22    paris
# 2   403  daddy   56  germany
# 3   404  simmi   45      goa

# %%
X = df.iloc[0:,0:3]
X
# Out:
#    roll   name  age
# 0   101  shalu   21
# 1   202  verma   22
# 2   403  daddy   56
# 3   404  simmi   45
# 4   105  priya   87

# %%
df
# Out:
#    roll   name  age     city
# 0   101  shalu   21   kanpur
# 1   202  verma   22    paris
# 2   403  daddy   56  germany
# 3   404  simmi   45      goa
# 4   105  priya   87    india

# %%
y = df.iloc[0:,0:4]
y
# Out:
#    roll   name  age     city
# 0   101  shalu   21   kanpur
# 1   202  verma   22    paris
# 2   403  daddy   56  germany
# 3   404  simmi   45      goa
# 4   105  priya   87    india

# %%
Z = df.iloc[:,2:]
Z
# Out:
#    age     city
# 0   21   kanpur
# 1   22    paris
# 2   56  germany
# 3   45      goa
# 4   87    india
